# %%
import requests as req
import json
from pprint import pprint
import pandas as pd
from pandas import DataFrame

# %%
url = "https://graph.facebook.com/v4.0/ads_archive?pretty=0&fields=ad_creative_body%2C%20ad_delivery_start_time%2C%20funding_entity%2C%20spend%2C%20impressions%2C%20region_distribution&search_terms=%22government%22&ad_active_status=INACTIVE&ad_type=POLITICAL_AND_ISSUE_ADS&ad_reached_countries=%5B%22US%22%5D&limit=200&after=c2NyYXBpbmdfY3Vyc29yOk1UVTJOalV4TkRjMU5qbzJNVEUyTlRVek1qWXdNalV5TmpNPQZDZD&access_token=EAAFO3I8XCgEBAKiuJLHxmH3mZAidUnK9o58i9xPyrqRvqIPxVUqYZBeLZAlZBhRKqKK7myj249wypaGoELSQR69FGVdLyKGB0no0EaQ9l4s8vTyh0leo0f1eqlAPuPAtYb26CtX5J0LfQMJoizOORVlccUT3CF8dWxxWENTKtndFZC37LpF5iy576em0neIEZD"

# %%
government_ads = req.get(url).json()

# %%
government_ads
# Out:
# {'data': [{'ad_creative_body': 'If you’re tired of Mitch McConnell’s broken Washington, then I need you on this team. Join me, and let’s take our government back.',
#    'ad_delivery_start_time': '2019-08-22T22:59:16+0000',
#    'funding_entity': 'Amy McGrath for Senate',
#    'spend': {'lower_bound': '0', 'upper_bound': '99'},
#    'impressions': {'lower_bound': '0', 'upper_bound': '999'},
#    'region_distribution': [{'percentage': '0.03125', 'region': 'Arizona'},
#     {'percentage': '0.03125', 'region': 'North Carolina'},
#     {'percentage': '0.03125', 'region': 'Washington'},
#     {'percentage': '0.03125', 'region': 'Virginia'},
#     {'percentage': '0.09375', 'region': 'Texas'},
#     {'percentage': '0.03125', 'region': 'South Dakota'},
#     {'percentage': '0.03125', 'region': 'South Carolina'},
#     {'percentage': '0.0625', 'region': 'Oklahoma'},
#     {'percentage': '0.09375', 'region': 'Ohio'},
#     {'percentage': '0.03125', 'region': 'New York'},
# ...

# %%
csv_path = "Output/government_ads.csv"

government_ads_df = pd.read_csv(csv_path, encoding="utf-8")
government_ads_df
# Out:
#                                       ad_creative_body  \
# 0    If you’re tired of Mitch McConnell’s broken Wa...
# 1    Just imagine: a Senate that works for US again...
# 2    This is UNDEMOCRATIC. The lack of internationa...
# 3    Legislation has been passed by Congress, which...
# 4    As President, I pledge to devise an administra...
# 5    As President, I pledge to devise an administra...
# 6    The federal government has become a revolving ...
# 7    The federal government has become a revolving ...
# 8    The federal government has become a revolving ...
# 9    As President, I pledge to devise an administra...
# 10   We are currently in the midst of a national cr...
# 11   Leaders work to solve problems. No one will wo...
# 12   We are currently in the midst of a national cr...
# 13   We are currently in the midst of a national cr...
# 14   The world is already facing an extinction cris...
# 15   We only have 60 days to get Congress to protec...
# ...
