# %%
import requests as req
import json
from pprint import pprint
import pandas as pd
from pandas import DataFrame

# %%
url = "https://graph.facebook.com/v4.0/ads_archive?pretty=0&fields=ad_creative_body%2C%20ad_delivery_start_time%2C%20funding_entity%2C%20spend%2C%20impressions%2C%20region_distribution&search_terms=%22kamala%20harris%22&ad_active_status=INACTIVE&ad_type=POLITICAL_AND_ISSUE_ADS&ad_reached_countries=%5B%22US%22%5D&limit=200&after=c2NyYXBpbmdfY3Vyc29yOk1UVTJOalUxT0RneU9EbzBNRFUyTnpZAeU1qWTNOVEF3TXpFPQZDZD&access_token=EAAFO3I8XCgEBAKiuJLHxmH3mZAidUnK9o58i9xPyrqRvqIPxVUqYZBeLZAlZBhRKqKK7myj249wypaGoELSQR69FGVdLyKGB0no0EaQ9l4s8vTyh0leo0f1eqlAPuPAtYb26CtX5J0LfQMJoizOORVlccUT3CF8dWxxWENTKtndFZC37LpF5iy576em0neIEZD"

# %%
harris_ads = req.get(url).json()

# %%
harris_ads
# Out:
# {'data': [{'ad_creative_body': 'Have you got plans for the September Democratic debate?\n\nHow about going to Houston to see Kamala take the stage? We’re bringing one supporter and a guest to the debate, and we want you to enter!\n\nPitch in any amount right now to be automatically entered to win a trip to join Kamala at the next Democratic debate in Houston in September.\n\nNo contrib. necessary to win. Void w/ prohibited. Ends. 8/31/19. Approx. prz value $5000. Subj. to Off. Rules.',
#    'ad_delivery_start_time': '2019-08-23T11:13:48+0000',
#    'funding_entity': 'Kamala Harris For The People',
#    'spend': {'lower_bound': '0', 'upper_bound': '99'},
#    'impressions': {'lower_bound': '0', 'upper_bound': '999'},
#    'region_distribution': [{'percentage': '0.01444', 'region': 'Alabama'},
#     {'percentage': '0.018051', 'region': 'Arkansas'},
#     {'percentage': '0.137184', 'region': 'Michigan'},
#     {'percentage': '0.001805', 'region': 'Mississippi'},
# ...

# %%
csv_path = "Output/harris_ads.csv"

harris_ads_df = pd.read_csv(csv_path, encoding="utf-8")
harris_ads_df
# Out:
#                                       ad_creative_body  \
# 0    Have you got plans for the September Democrati...
# 1    Have you got plans for the September Democrati...
# 2    Donate any amount now to be automatically ente...
# 3    Donate any amount now to be automatically ente...
# 4    You can enter to win a chance to watch the nex...
# 5    Already, Joe Biden, Kirsten Gillibrand, Tom St...
# 6    Already, Joe Biden, Kirsten Gillibrand, Tom St...
# 7    Kamala Harris, the radical Senator from Califo...
# 8    With our campaign gaining momentum -- the late...
# 9    With our campaign gaining momentum -- the late...
# 10   You can enter to win a chance to watch the nex...
# 11   Have you got plans for the September Democrati...
# 12   You can enter to win a chance to watch the nex...
# 13   Have you got plans for the September Democrati...
# 14   Donate any amount now to be automatically ente...
# 15   Donate any amount now to be automatically ente...
# ...
