# %%
import requests as req
import json
from pprint import pprint
import pandas as pd
from pandas import DataFrame

# %%
url = "https://graph.facebook.com/v4.0/ads_archive?pretty=0&fields=ad_creative_body%2C%20ad_delivery_start_time%2C%20funding_entity%2C%20spend%2C%20impressions%2C%20region_distribution&search_terms=%22independent%22&ad_active_status=INACTIVE&ad_type=POLITICAL_AND_ISSUE_ADS&ad_reached_countries=%5B%22US%22%5D&limit=200&after=c2NyYXBpbmdfY3Vyc29yOk1UVTJOakkzTXprd01qb3pPVFV4TmpRd01qUTBOamd4T0RNPQZDZD&access_token=EAAFO3I8XCgEBALc6w4VgpL6NVrsZCZAOBT7fHtJIwqFvvuQJZCClZCqOHjM6D5ZBVtvRtRMokplJH9F6EbZBvVwcqDSCHA3gSKUM3tbMBVGR36bcjujuUzKgWOZBJZBMACZAvkMZB5tZCZBBKQnB8VU1ZA7gyVOaR51bG3TRieJob3qWoWwSyyr8YxAch3kgfZCra79ANjvH5hvKMZAEwZDZD"

# %%
independent_ads = req.get(url).json()

# %%
independent_ads
# Out:
# {'data': [{'ad_creative_body': 'What happens to the Transportation industry, Truckers who for some have done only that their whole lives?   I have 6 years of trucking experience, the parking and fueling is already a nightmare because of the ELD\'s, so we want to add emission free trucks? Charging electric would be near impossible! \nIf the Green New Deal passes...\n\n"overhauling transportation systems in \nthe United States to remove pollution and \n greenhouse gas emissions from the transportation sector as much as is technologically feasible"',
#    'ad_delivery_start_time': '2019-08-20T02:05:47+0000',
#    'funding_entity': 'Steve Mazur Candidate For Congress ',
#    'spend': {'lower_bound': '0', 'upper_bound': '99'},
#    'impressions': {'lower_bound': '0', 'upper_bound': '999'},
#    'region_distribution': [{'percentage': '1', 'region': 'Texas'}]},
#   {'ad_creative_body': 'I went to the school of hard knocks, and have seen the real world, not the fantasy that...',
# ...

# %%
csv_path = "Output/independent_ads.csv"

independent_ads_df = pd.read_csv(csv_path, encoding="utf-8")
independent_ads_df
# Out:
#                                       ad_creative_body  \
# 0    What happens to the Transportation industry, T...
# 1    I went to the school of hard knocks, and have ...
# 2    Trump's statement on the success of the NY tim...
# 3    After a recent court ruling about independent ...
# 4    COMING SOON! Mental health professionals FINAL...
# 5    Liz De La Torre will be a bold advocate for a ...
# 6    Liz De La Torre’s plan includes pre-kindergart...
# 7    Liz De La Torre is a daughter of immigrants, a...
# 8    Liz De La Torre fights for support and justice...
# 9    Liz De La Torre: Police profiling breaks commu...
# 10   Climate change is real, and we need a plan for...
# 11   Liz De La Torre will ban “crisis pregnancy cli...
# 12   We deserve paid time to care for our families....
# 13   For Over 25 Years Kat Copeland Has Been An Ind...
# 14   Working people cannot wait for someone to solv...
# 15   ONLY FEW ONLINE TICKETS REMAINING! Purchase yo...
# ...
