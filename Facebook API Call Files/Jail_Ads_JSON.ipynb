# %%
import requests as req
import json
from pprint import pprint
import pandas as pd
from pandas import DataFrame

# %%
url = "https://graph.facebook.com/v4.0/ads_archive?pretty=0&fields=ad_creative_body%2C%20ad_delivery_start_time%2C%20funding_entity%2C%20spend%2C%20impressions%2C%20region_distribution&search_terms=%22jail%22&ad_active_status=INACTIVE&ad_type=POLITICAL_AND_ISSUE_ADS&ad_reached_countries=%5B%22US%22%5D&limit=200&after=c2NyYXBpbmdfY3Vyc29yOk1UVTJOalF6T0RrNE16b3hNRGt3T1RNNU5Ua3hNVEEwTXpFeAZDZD&access_token=EAAFO3I8XCgEBAKiuJLHxmH3mZAidUnK9o58i9xPyrqRvqIPxVUqYZBeLZAlZBhRKqKK7myj249wypaGoELSQR69FGVdLyKGB0no0EaQ9l4s8vTyh0leo0f1eqlAPuPAtYb26CtX5J0LfQMJoizOORVlccUT3CF8dWxxWENTKtndFZC37LpF5iy576em0neIEZD"

# %%
jail_ads = req.get(url).json()

# %%
jail_ads
# Out:
# {'data': [{'ad_creative_body': "The Mueller investigation resulted in 37 indictments, 7 guilty pleas, and 10 possible instances of obstruction of justice. If anyone else did this, they'd go to jail. Add your name to tell Congress: no one is above the law.",
#    'ad_delivery_start_time': '2019-08-22T01:56:23+0000',
#    'funding_entity': 'Need to Impeach',
#    'spend': {'lower_bound': '100', 'upper_bound': '499'},
#    'impressions': {'lower_bound': '5000', 'upper_bound': '9999'},
#    'region_distribution': [{'percentage': '1', 'region': 'Michigan'}]},
#   {'ad_creative_body': "The Mueller investigation resulted in 37 indictments, 7 guilty pleas, and 10 possible instances of obstruction of justice. If anyone else did this, they'd go to jail. Add your name to tell Congress: no one is above the law.",
#    'ad_delivery_start_time': '2019-08-22T01:56:23+0000',
#    'funding_entity': 'Need to Impeach',
#    'spend': {'lower_bound': '100', 'upper_bound': '499'},
# ...

# %%
csv_path = "Output/jail_ads.csv"

jail_ads_df = pd.read_csv(csv_path, encoding="utf-8")
jail_ads_df
# Out:
#                                       ad_creative_body  \
# 0    The Mueller investigation resulted in 37 indic...
# 1    The Mueller investigation resulted in 37 indic...
# 2    The Mueller investigation resulted in 37 indic...
# 3    The Mueller investigation resulted in 37 indic...
# 4    The Mueller investigation resulted in 37 indic...
# 5    The Mueller investigation resulted in 37 indic...
# 6    The Mueller investigation resulted in 37 indic...
# 7    The Mueller investigation resulted in 37 indic...
# 8    The Mueller investigation resulted in 37 indic...
# 9    The Mueller investigation resulted in 37 indic...
# 10   The Mueller investigation resulted in 37 indic...
# 11   No Political Censorship, No Shadow-banning, No...
# 12   No Political Censorship, No Shadow-banning, No...
# 13   Knowing when to use force or deadly force can ...
# 14   Knowing when to use force or deadly force can ...
# 15   Knowing when to use force or deadly force can ...
# ...
