# %%
import requests as req
import json
from pprint import pprint
import pandas as pd
from pandas import DataFrame

# %%
url = "https://graph.facebook.com/v4.0/ads_archive?pretty=0&fields=ad_creative_body%2C%20ad_delivery_start_time%2C%20funding_entity%2C%20spend%2C%20impressions%2C%20region_distribution&search_terms=%22cory%20booker%22&ad_active_status=INACTIVE&ad_type=POLITICAL_AND_ISSUE_ADS&ad_reached_countries=%5B%22US%22%5D&limit=200&after=c2NyYXBpbmdfY3Vyc29yOk1UVTJOVGszTnpFME1EbzBNRGt5TXpBeU1qazNNRE13TURZAPQZDZD&access_token=EAAFO3I8XCgEBAKiuJLHxmH3mZAidUnK9o58i9xPyrqRvqIPxVUqYZBeLZAlZBhRKqKK7myj249wypaGoELSQR69FGVdLyKGB0no0EaQ9l4s8vTyh0leo0f1eqlAPuPAtYb26CtX5J0LfQMJoizOORVlccUT3CF8dWxxWENTKtndFZC37LpF5iy576em0neIEZD"

# %%
booker_ads = req.get(url).json()

# %%
booker_ads
# Out:
# {'data': [{'ad_creative_body': 'Amy Klobuchar and Andrew Yang just qualified for the fall debates. And Julián Castro and Tulsi Gabbard are on the cusp of getting there as well.\n\nWith more and more candidates qualifying every day -- bringing the number of candidates on stage to nine -- we need to make sure this underdog campaign stands out.\n\nWill you chip in to help us amplify our campaign’s message?',
#    'ad_delivery_start_time': '2019-08-16T17:39:00+0000',
#    'funding_entity': 'Cory 2020',
#    'spend': {'lower_bound': '0', 'upper_bound': '99'},
#    'impressions': {'lower_bound': '0', 'upper_bound': '999'},
#    'region_distribution': [{'percentage': '0.022901', 'region': 'Arizona'},
#     {'percentage': '0.045802', 'region': 'Texas'},
#     {'percentage': '0.007634', 'region': 'Vermont'},
#     {'percentage': '0.015267', 'region': 'Wisconsin'},
#     {'percentage': '0.007634', 'region': 'Utah'},
#     {'percentage': '0.175573', 'region': 'California'},
# ...

# %%
csv_path = "Output/booker_ads.csv"

booker_ads_df = pd.read_csv(csv_path, encoding="utf-8")
booker_ads_df
# Out:
#                                       ad_creative_body  \
# 0    Amy Klobuchar and Andrew Yang just qualified f...
# 1    Amy Klobuchar and Andrew Yang just qualified f...
# 2    Amy Klobuchar and Andrew Yang just qualified f...
# 3    Amy Klobuchar and Andrew Yang just qualified f...
# 4    Amy Klobuchar and Andrew Yang just qualified f...
# 5    Amy Klobuchar and Andrew Yang just qualified f...
# 6    Amy Klobuchar and Andrew Yang just qualified f...
# 7    Amy Klobuchar and Andrew Yang just qualified f...
# 8    Amy Klobuchar and Andrew Yang just qualified f...
# 9    Amy Klobuchar and Andrew Yang just qualified f...
# 10   Rep. Steve King just attacked me for defending...
# 11   Rep. Steve King just attacked me for defending...
# 12   Rep. Steve King just attacked me for defending...
# 13   Rep. Steve King just attacked me for defending...
# 14   Rep. Steve King just attacked me for defending...
# 15   Rep. Steve King just attacked me for defending...
# ...
