# %%
import requests as req
import json
from pprint import pprint
import pandas as pd
from pandas import DataFrame

# %%
url = "https://graph.facebook.com/v4.0/ads_archive?pretty=0&fields=ad_creative_body%2C%20ad_delivery_start_time%2C%20funding_entity%2C%20spend%2C%20impressions%2C%20region_distribution&search_terms=%22joe%20biden%22&ad_active_status=INACTIVE&ad_type=POLITICAL_AND_ISSUE_ADS&ad_reached_countries=%5B%22US%22%5D&limit=200&after=c2NyYXBpbmdfY3Vyc29yOk1UVTJOalE1TkRFNE1EbzBOekUwTVRZAME9EY3dNVE0xTnpBPQZDZD&access_token=EAAFO3I8XCgEBAKiuJLHxmH3mZAidUnK9o58i9xPyrqRvqIPxVUqYZBeLZAlZBhRKqKK7myj249wypaGoELSQR69FGVdLyKGB0no0EaQ9l4s8vTyh0leo0f1eqlAPuPAtYb26CtX5J0LfQMJoizOORVlccUT3CF8dWxxWENTKtndFZC37LpF5iy576em0neIEZD"

# %%
biden_ads = req.get(url).json()

# %%
biden_ads
# Out:
# {'data': [{'ad_creative_body': 'You heard it from Joe Biden first: Cory Booker’s our future president. Want to support Cory at the next debate? Chip in right now and you’ll be automatically entered for a chance to win a trip for you and a guest -- your flight and stay in Houston on us.',
#    'ad_delivery_start_time': '2019-08-22T17:16:20+0000',
#    'funding_entity': 'Cory 2020',
#    'spend': {'lower_bound': '0', 'upper_bound': '99'},
#    'impressions': {'lower_bound': '0', 'upper_bound': '999'},
#    'region_distribution': [{'percentage': '0.166667', 'region': 'Iowa'},
#     {'percentage': '0.166667', 'region': 'Massachusetts'},
#     {'percentage': '0.166667', 'region': 'Michigan'},
#     {'percentage': '0.166667', 'region': 'New Hampshire'},
#     {'percentage': '0.166667', 'region': 'New Jersey'},
#     {'percentage': '0.166667', 'region': 'Ohio'}]},
# ...

# %%
csv_path = "Output/biden_ads.csv"

biden_ads_df = pd.read_csv(csv_path, encoding="utf-8")
biden_ads_df
# Out:
#                                       ad_creative_body  \
# 0    You heard it from Joe Biden first: Cory Booker...
# 1    You heard it from Joe Biden first: Cory Booker...
# 2    Our next president should ensure rights for al...
# 3    Our next president should ensure rights for al...
# 4    Our next president should ensure rights for al...
# 5    Our next president should ensure rights for al...
# 6    Our next president should ensure rights for al...
# 7    Our next president should ensure rights for al...
# 8    When former Vice President Joe Biden announced...
# 9    Team Joe has been growing in New Hampshire - a...
# 10   New Hampshire - you know this election is diff...
# 11   Donald Trump has shown that his campaign is go...
# 12   Donald Trump has shown that his campaign is go...
# 13   Team Joe has been growing in New Hampshire - a...
# 14   Donald Trump has shown that his campaign is go...
# 15   New Hampshire - you know this election is diff...
# ...
