# %%
import requests as req
import json
from pprint import pprint
import pandas as pd
from pandas import DataFrame

# %%
url = "https://graph.facebook.com/v4.0/ads_archive?pretty=0&fields=ad_creative_body%2C%20ad_delivery_start_time%2C%20funding_entity%2C%20spend%2C%20impressions%2C%20region_distribution&search_terms=%22ku%20klux%20klan%22&ad_active_status=INACTIVE&ad_type=POLITICAL_AND_ISSUE_ADS&ad_reached_countries=%5B%22US%22%5D&limit=200&after=c2NyYXBpbmdfY3Vyc29yOk1UVTFNakV6TWpneE9Eb3lNak0zT1RFek1ERXpNVFF5TmpjeQZDZD&access_token=EAAFO3I8XCgEBAKiuJLHxmH3mZAidUnK9o58i9xPyrqRvqIPxVUqYZBeLZAlZBhRKqKK7myj249wypaGoELSQR69FGVdLyKGB0no0EaQ9l4s8vTyh0leo0f1eqlAPuPAtYb26CtX5J0LfQMJoizOORVlccUT3CF8dWxxWENTKtndFZC37LpF5iy576em0neIEZD"

# %%
kkk_ads = req.get(url).json()

# %%
kkk_ads
# Out:
# {'data': [{'ad_creative_body': '“For 40 years, justice had gone undone in the brutal murder of four young girls in the Sixteenth Street Baptist Church. [...] Doug Jones said no more. Justice had to be done. Those young girls deserved it. Their families deserved it.” —former vice president Joe Biden\n\nWatch Sen. Jones discuss his new book, Bending Toward Justice--the story of the decades-long fight to bring justice to the victims of the 16th Street Baptist Church bombing.\n\nFind out more about the book here: http://bit.ly/bendingtowardsjustice',
#    'ad_delivery_start_time': '2019-03-08T16:45:16+0000',
#    'funding_entity': "St. Martin's Press",
#    'spend': {'lower_bound': '500', 'upper_bound': '999'},
#    'impressions': {'lower_bound': '50000', 'upper_bound': '99999'},
#    'region_distribution': [{'percentage': '0.065631', 'region': 'Alabama'},
#     {'percentage': '0.021507', 'region': 'Pennsylvania'},
#     {'percentage': '0.003334', 'region': 'Nevada'},
# ...

# %%
csv_path = "Output/kkk_ads.csv"

kkk_ads_df = pd.read_csv(csv_path, encoding="utf-8")
kkk_ads_df
# Out:
#                                      ad_creative_body  \
# 0   “For 40 years, justice had gone undone in the ...
# 1   “For 40 years, justice had gone undone in the ...
# 2   In 1964, national attention turned to Mississi...
# 3   PLEASE NOTE: Although this event is FREE and o...
# 4   PLEASE NOTE: Although this event is FREE and o...
# 5   In 1964, national attention turned to Mississi...
# 6   The Democrat-Reporter, an Alabama newspaper, r...
# 7   The Democrat-Reporter, an Alabama newspaper, r...
# 8   AARP members & non-members are invited to a fr...
# 9   Ibraheem Samirah is the Democrat candidate in ...
# 10  INSTALL NEW KLAN AT SMYRNA\r\n\r\nNashville Ba...
# 11  Many new disturbing images of white men, namel...
# 12  "Black Virginia voters feel betrayed, left in ...
# 13  Hoodless\r\n\r\nWest Virginia Republican Deleg...
# 14  Hoodless\r\n\r\nWest Virginia Republican Deleg...
# 15  "Even in the least appalling reading of his co...
# ...
