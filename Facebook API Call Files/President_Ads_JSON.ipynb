# %%
import requests as req
import json
from pprint import pprint
import pandas as pd
from pandas import DataFrame

# %%
url = "https://graph.facebook.com/v4.0/ads_archive?pretty=0&fields=ad_creative_body%2C%20ad_delivery_start_time%2C%20funding_entity%2C%20spend%2C%20impressions%2C%20region_distribution&search_terms=%22president%22&ad_active_status=INACTIVE&ad_type=POLITICAL_AND_ISSUE_ADS&ad_reached_countries=%5B%22US%22%5D&limit=200&after=c2NyYXBpbmdfY3Vyc29yOk1UVTJOalUzT0RFd01qb3pPRGszTnpBMk9URTNNemd6TURBPQZDZD&access_token=EAAFO3I8XCgEBAKiuJLHxmH3mZAidUnK9o58i9xPyrqRvqIPxVUqYZBeLZAlZBhRKqKK7myj249wypaGoELSQR69FGVdLyKGB0no0EaQ9l4s8vTyh0leo0f1eqlAPuPAtYb26CtX5J0LfQMJoizOORVlccUT3CF8dWxxWENTKtndFZC37LpF5iy576em0neIEZD"

# %%
president_ads = req.get(url).json()

# %%
president_ads
# Out:
# {'data': [{'ad_creative_body': 'Liberal California politicians want to keep President Trump off the 2020 ballot. This law is UNCONSTITUTIONAL.\n\nDemand President Trump is on the ballot. SB27 is WRONG for California. \n\nSign up NOW and join the legal fight!',
#    'ad_delivery_start_time': '2019-08-23T16:35:02+0000',
#    'funding_entity': 'California Republican Party',
#    'spend': {'lower_bound': '0', 'upper_bound': '99'},
#    'impressions': {'lower_bound': '0', 'upper_bound': '999'},
#    'region_distribution': [{'percentage': '1', 'region': 'California'}]},
#   {'ad_creative_body': "Governor Newsom signed SB27, preventing President Trump from appearing on next year's ballot.\n \nThe law is clearly UNCONSTITUTIONAL and disenfranchises millions of California voters. We need your support to OVERTURN SB27! DEMAND President Trump is on the ballot. \n\nJOIN THE LEGAL FIGHT NOW >>>",
#    'ad_delivery_start_time': '2019-08-23T16:35:02+0000',
# ...

# %%
csv_path = "Output/president_ads.csv"

president_ads_df = pd.read_csv(csv_path, encoding="utf-8")
president_ads_df
# Out:
#                                       ad_creative_body  \
# 0    Liberal California politicians want to keep Pr...
# 1    Governor Newsom signed SB27, preventing Presid...
# 2    Demand President Trump is on the ballot. SB27 ...
# 3    URGENT REQUEST: Demand President Trump is on t...
# 4    URGENT REQUEST: Demand President Trump is on t...
# 5    Demand President Trump is on the ballot. SB27 ...
# 6    Governor Newsom signed SB27, preventing Presid...
# 7    Demand President Trump is on the ballot. SB27 ...
# 8    Governor Newsom signed SB27, preventing Presid...
# 9    Liberal California politicians want to keep Pr...
# 10   URGENT REQUEST: Demand President Trump is on t...
# 11   President Trump needs to know YOU stand with h...
# 12   URGENT REQUEST: Demand President Trump is on t...
# 13   Liberal California politicians want to keep Pr...
# 14   Liberal California politicians want to keep Pr...
# 15   Liberal California politicians want to keep Pr...
# ...
