# %%
import requests as req
import json
from pprint import pprint
import pandas as pd
from pandas import DataFrame

# %%
url = "https://graph.facebook.com/v4.0/ads_archive?pretty=0&fields=ad_creative_body%2C%20ad_delivery_start_time%2C%20funding_entity%2C%20spend%2C%20impressions%2C%20region_distribution&search_terms=%22incarceration%22&ad_active_status=INACTIVE&ad_type=POLITICAL_AND_ISSUE_ADS&ad_reached_countries=%5B%22US%22%5D&limit=200&after=c2NyYXBpbmdfY3Vyc29yOk1UVTJOalE0TmpBek5UbzNNakUzTXpRM01qUTVNamN6TkRrPQZDZD&access_token=EAAFO3I8XCgEBAKiuJLHxmH3mZAidUnK9o58i9xPyrqRvqIPxVUqYZBeLZAlZBhRKqKK7myj249wypaGoELSQR69FGVdLyKGB0no0EaQ9l4s8vTyh0leo0f1eqlAPuPAtYb26CtX5J0LfQMJoizOORVlccUT3CF8dWxxWENTKtndFZC37LpF5iy576em0neIEZD"

# %%
incarceration_ads = req.get(url).json()

# %%
incarceration_ads
# Out:
# {'data': [{'ad_creative_body': 'Think of the future our kids could have if we invested in our community instead of mass incarceration. It starts with a vote.',
#    'ad_delivery_start_time': '2019-08-21T19:15:35+0000',
#    'funding_entity': 'Progress Virginia',
#    'spend': {'lower_bound': '0', 'upper_bound': '99'},
#    'impressions': {'lower_bound': '0', 'upper_bound': '999'},
#    'region_distribution': [{'percentage': '1', 'region': 'Virginia'}]},
#   {'ad_creative_body': 'Think of the future our kids could have if we invested in our community instead of mass incarceration. It starts with a vote.',
#    'ad_delivery_start_time': '2019-08-21T19:15:35+0000',
#    'funding_entity': 'Progress Virginia',
#    'spend': {'lower_bound': '0', 'upper_bound': '99'},
#    'impressions': {'lower_bound': '0', 'upper_bound': '999'},
#    'region_distribution': [{'percentage': '1', 'region': 'Virginia'}]},
# ...

# %%
csv_path = "Output/incarceration_ads.csv"

incarceration_ads_df = pd.read_csv(csv_path, encoding="utf-8")
incarceration_ads_df
# Out:
#                                       ad_creative_body  \
# 0    Think of the future our kids could have if we ...
# 1    Think of the future our kids could have if we ...
# 2    Think of the future our kids could have if we ...
# 3    Think of the future our kids could have if we ...
# 4    Think of the future our kids could have if we ...
# 5    Think of the future our kids could have if we ...
# 6    Think of the future our kids could have if we ...
# 7    Think of the future our kids could have if we ...
# 8    Think of the future our kids could have if we ...
# 9    Think of the future our kids could have if we ...
# 10   Think of the future our kids could have if we ...
# 11   Think of the future our kids could have if we ...
# 12   Think of the future our kids could have if we ...
# 13   Think of the future our kids could have if we ...
# 14   Think of the future our kids could have if we ...
# 15   Think of the future our kids could have if we ...
# ...
