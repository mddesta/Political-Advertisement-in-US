# %%
import requests as req
import json
from pprint import pprint
import pandas as pd
from pandas import DataFrame

# %%
url = "https://graph.facebook.com/v4.0/ads_archive?pretty=0&fields=ad_creative_body%2C%20ad_delivery_start_time%2C%20funding_entity%2C%20spend%2C%20impressions%2C%20region_distribution&search_terms=%22white%22&ad_active_status=INACTIVE&ad_type=POLITICAL_AND_ISSUE_ADS&ad_reached_countries=%5B%22US%22%5D&limit=200&after=c2NyYXBpbmdfY3Vyc29yOk1UVTJOalF5TXpjMU1qb3lOREF4TkRjMk56UXpNamd4T1RNdwZDZD&access_token=EAAFO3I8XCgEBAGcSlvWL3Qd6SEPC0PZC6yaqZCf5xb71bWHAsvUTcd8ZCdDvTyxG95Y5XQoFZBepSKtYOl9TzGZAxLqEt6wDxMZBAy8eZAUnJkvdcOaycZB2EbxpOJyWJZC3F86k2RLOvhnva5fMQxO77MZA7EFUuM5wyxSe9pr9tAwb6pYo6S9J03bCgBvuzzPSQnDyxLxP6TiwZDZD"

# %%
white_ads = req.get(url).json()

# %%
white_ads
# Out:
# {'data': [{'ad_creative_body': "🇺🇸Trump 2020🇺🇸 , Autographed presidential mug\nLet's make Liberals Cry Again!\n\nAvailable Here : http://thetrumpshopping.com/coffe-mug\n\nThese are limited, so we only have 350 available.\nIf you cant add it to cart, we are sold out.",
#    'ad_delivery_start_time': '2019-08-21T21:42:28+0000',
#    'funding_entity': 'Presticlick Media',
#    'spend': {'lower_bound': '0', 'upper_bound': '99'},
#    'impressions': {'lower_bound': '0', 'upper_bound': '999'},
#    'region_distribution': [{'percentage': '0.010811', 'region': 'Alabama'},
#     {'percentage': '0.064865', 'region': 'Texas'},
#     {'percentage': '0.086486', 'region': 'New York'},
#     {'percentage': '0.027027', 'region': 'North Carolina'},
#     {'percentage': '0.054054', 'region': 'Ohio'},
#     {'percentage': '0.021622', 'region': 'Oklahoma'},
#     {'percentage': '0.027027', 'region': 'Oregon'},
#     {'percentage': '0.027027', 'region': 'Pennsylvania'},
# ...

# %%
csv_path = "Output/white_ads.csv"

white_ads_df = pd.read_csv(csv_path, encoding="utf-8")
white_ads_df
# Out:
#                                       ad_creative_body  \
# 0    🇺🇸Trump 2020🇺🇸 , Autographed presidential mug\...
# 1    August recess is NOT a vacation. August is a c...
# 2    Our grassroots organizing is working—a majorit...
# 3    August recess is NOT a vacation. August is a c...
# 4    August recess is NOT a vacation. August is a c...
# 5    Our grassroots organizing is working—a majorit...
# 6    Our grassroots organizing is working—a majorit...
# 7    August recess is NOT a vacation. August is a c...
# 8    Our grassroots organizing is working—a majorit...
# 9    Our grassroots organizing is working—a majorit...
# 10   Our grassroots organizing is working—a majorit...
# 11   August recess is NOT a vacation. August is a c...
# 12   August recess is NOT a vacation. August is a c...
# 13   Our grassroots organizing is working—a majorit...
# 14   August recess is NOT a vacation. August is a c...
# 15   August recess is NOT a vacation. August is a c...
# ...
