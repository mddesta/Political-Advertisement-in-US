# %%
import requests as req
import json
from pprint import pprint
import pandas as pd
from pandas import DataFrame

# %%
url = "https://graph.facebook.com/v4.0/ads_archive?pretty=0&fields=ad_creative_body%2C%20ad_delivery_start_time%2C%20funding_entity%2C%20spend%2C%20impressions%2C%20region_distribution&search_terms=%22bernie%20sanders%22&ad_active_status=INACTIVE&ad_type=POLITICAL_AND_ISSUE_ADS&ad_reached_countries=%5B%22US%22%5D&limit=200&after=c2NyYXBpbmdfY3Vyc29yOk1UVTJOalV3TlRneU1qb3lNelEzTnpRek16RTFORGMyTmpjdwZDZD&access_token=EAAFO3I8XCgEBAKiuJLHxmH3mZAidUnK9o58i9xPyrqRvqIPxVUqYZBeLZAlZBhRKqKK7myj249wypaGoELSQR69FGVdLyKGB0no0EaQ9l4s8vTyh0leo0f1eqlAPuPAtYb26CtX5J0LfQMJoizOORVlccUT3CF8dWxxWENTKtndFZC37LpF5iy576em0neIEZD"

# %%
sanders_ads = req.get(url).json()

# %%
sanders_ads
# Out:
# {'data': [{'ad_creative_body': "The climate crisis is not only the single greatest challenge facing our country – it is also our single greatest opportunity to build a more just and equitable future. \n\nThat’s why Bernie just released a Green New Deal plan to solve the climate crisis AND build an economy that works for all. Add your name to support Bernie's plan.",
#    'ad_delivery_start_time': '2019-08-22T20:30:22+0000',
#    'funding_entity': 'Bernie 2020.',
#    'spend': {'lower_bound': '0', 'upper_bound': '99'},
#    'impressions': {'lower_bound': '0', 'upper_bound': '999'},
#    'region_distribution': [{'percentage': '1', 'region': 'Washington'}]},
#   {'ad_creative_body': 'How Bernie Sanders would boost unions and eliminate right to work laws',
#    'ad_delivery_start_time': '2019-08-22T09:44:08+0000',
#    'funding_entity': "Break'n News",
#    'spend': {'lower_bound': '0', 'upper_bound': '99'},
#    'impressions': {'lower_bound': '0', 'upper_bound': '999'},
# ...

# %%
csv_path = "Output/sanders_ads.csv"

sanders_ads_df = pd.read_csv(csv_path, encoding="utf-8")
sanders_ads_df
# Out:
#                                       ad_creative_body  \
# 0    The climate crisis is not only the single grea...
# 1    How Bernie Sanders would boost unions and elim...
# 2    Bernie Sanders would like to hear directly fro...
# 3    Bernie Sanders would like to hear directly fro...
# 4    Bernie Sanders would like to hear directly fro...
# 5    Many people feel like Bernie Sanders could hav...
# 6    Many people feel like Bernie Sanders could hav...
# 7    Bernie Sanders would like to hear directly fro...
# 8    Bernie Sanders would like to hear directly fro...
# 9    Bernie Sanders would like to hear directly fro...
# 10   Bernie Sander's campaign is taking on Wall Str...
# 11   Bernie Sander's campaign is taking on Wall Str...
# 12   Bernie Sander's campaign is taking on Wall Str...
# 13   Bernie Sander's campaign is taking on Wall Str...
# 14   Bernie Sander's campaign is taking on Wall Str...
# 15   Bernie Sander's campaign is taking on Wall Str...
# ...
