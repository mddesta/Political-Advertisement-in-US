# %%
import numpy as np
import pandas as pd
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("FB_IRA_Cleaned.csv")
df.head()
# Out:
#    Unnamed: 0  adID                                             adText  \
# 0           0   487  Join our rally atFree the patriots stand for l...
# 1           1   515  Join our rally atFree the patriots stand for l...
# 2           2   532  Join our rally atFree the patriots stand for l...
# 3           3  1863  When ur credit card gets declined and u\nprete...
# 4           4  3307  Photo by Isadora Kosofskypart of an ongoing se...
#
#                                         adText_clean  \
# 0  Join our rally atFree the patriots stand for l...
# 1  Join our rally atFree the patriots stand for l...
# 2  Join our rally atFree the patriots stand for l...
# 3  When ur credit card gets declined and u\nprete...
# 4  Photo by Isadora Kosofskypart of an ongoing se...
#
#                                     adText_tokenized  \
# 0  ['join', 'our', 'rally', 'atfree', 'the', 'pat...
# 1  ['join', 'our', 'rally', 'atfree', 'the', 'pat...
# 2  ['join', 'our', 'rally', 'atfree', 'the', 'pat...
# 3  ['when', 'ur', 'credit', 'card', 'gets', 'decl...
# 4  ['photo', 'by', 'isadora', 'kosofskypart', 'of...
#
#                                        adText_nostop  \
# 0  ['join', 'rally', 'atfree', 'patriots', 'stand...
# 1  ['join', 'rally', 'atfree', 'patriots', 'stand...
# 2  ['join', 'rally', 'atfree', 'patriots', 'stand...
# 3  ['ur', 'credit', 'card', 'gets', 'declined', '...
# 4  ['photo', 'isadora', 'kosofskypart', 'ongoing'...
#
#                                       adText_stemmed  \
# 0  ['join', 'ralli', 'atfre', 'patriot', 'stand',...
# 1  ['join', 'ralli', 'atfre', 'patriot', 'stand',...
# 2  ['join', 'ralli', 'atfre', 'patriot', 'stand',...
# 3  ['ur', 'credit', 'card', 'get', 'declin', 'u',...
# 4  ['photo', 'isadora', 'kosofskypart', 'ongo', '...
#
#                                    adText_lemmatized  adText_len  punct%  \
# 0  ['join', 'rally', 'atfree', 'patriot', 'stand'...          56     0.0
# 1  ['join', 'rally', 'atfree', 'patriot', 'stand'...          56     0.0
# 2  ['join', 'rally', 'atfree', 'patriot', 'stand'...          56     0.0
# 3  ['ur', 'credit', 'card', 'get', 'declined', 'u...          93     0.0
# 4  ['photo', 'isadora', 'kosofskypart', 'ongoing'...         147     0.0
#
#   label  ID
# 0   IRA   0
# 1   IRA   1
# 2   IRA   2
# 3   IRA   3
# 4   IRA   4

# %%
text = " ".join(text for text in df.adText_lemmatized)
stopwords = set(STOPWORDS)
wordcloud = WordCloud(stopwords=stopwords, background_color="white").generate(text)

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.savefig("wordcloud.png")
